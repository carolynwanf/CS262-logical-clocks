# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
color_dict = {
    1: 'darkorange',
    2: 'mediumturquoise',
    3: 'darkorchid',
    4: 'cornflowerblue',
    5: 'firebrick',
    6: 'mediumseagreen'
}

# %%
# variable naming scheme:
#   mi_tj_ck = data for machine i in trial j which had clock speed k
m0_t1_c2 = pd.read_csv('./Trial1/machine0clock_speed2log.csv')
m1_t1_c4 = pd.read_csv('./Trial1/machine1clock_speed4log.csv')
m2_t1_c5 = pd.read_csv('./Trial1/machine2clock_speed5log.csv')

# %%
mega_max = max(max(m0_t1_c2['logical_clock_time']), max(m1_t1_c4['logical_clock_time']), max(m2_t1_c5['logical_clock_time']))

plt.plot(m0_t1_c2['system_time'], m0_t1_c2['logical_clock_time']/mega_max, c=color_dict[2])
plt.plot(m1_t1_c4['system_time'], m1_t1_c4['logical_clock_time']/mega_max, c=color_dict[4])
plt.plot(m2_t1_c5['system_time'], m2_t1_c5['logical_clock_time']/mega_max, c=color_dict[5])

# %%
# m2_m0_delta = m2_t1_c5['logical_clock_time'] - m0_t1_c2['logical_clock_time']
# m2_m1_delta = m2_t1_c5['logical_clock_time'] - m1_t1_c4['logical_clock_time']

# plt.plot(m1_t1_c4['system_time'], m2_m1_delta)
# plt.plot(m0_t1_c2['system_time'], m2_m0_delta)
